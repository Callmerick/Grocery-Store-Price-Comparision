# %%
from selenium import webdriver
from datetime import date
import time
from bs4 import BeautifulSoup
import urllib.request
import pandas as pd
import numpy as np

#Open a new web browser
driver = webdriver.Chrome()

#Open the web page that we want open and log in
driver.get('https://www.walmart.com/grocery/browse/Seafood?aisle=1255027787101_1255027789152')

time.sleep(10)

#Grab the webpage as a BeautifulSoup object
soup = BeautifulSoup(driver.page_source,'html.parser')

#Close the webpage
driver.close()

#Obtain Product Names and append to blank list
productNames = soup.find_all("a",class_='productTile__productNameContainer___3wOJS')
cProductNames1 = []                              
for i in range(len(productNames)):
    cProductNames1.append(productNames[i].text.strip())
cProductNames1 = [i.split(",")[0] for i in cProductNames1]

#Checks if a product is in stock, and if so, obtains the Product Price and append to a blank list
checkStock = soup.find_all(class_='productTile__productTileWrapper___G0H8Q')
outOfStock = []
productPrice = soup.find_all("span",class_='Price__salePrice___3YEJa')
cProductPrice1 = []

for i in range(len(checkStock)):
    if 'productTile__outOfStock___2Dlcs' in str(checkStock[i]):
        outOfStock.append("Y")     
    else:
        outOfStock.append("N")

for i in range(len(outOfStock)):
    if outOfStock[i] == "N":
        cProductPrice1.append(productPrice[i].text.strip())
    else:
        cProductPrice1.append(" Out of Stock")
cProductPrice1 = [e[1:] for e in cProductPrice1]

pricePerUnit = soup.find_all("a",class_='productTile__productNameContainer___3wOJS')
cPricePerUnit1 = []                            
for i in range(len(pricePerUnit)):
    cPricePerUnit1.append(productNames[i].text.strip())
cPricePerUnit1 = [e.partition(',')[2] for e in cPricePerUnit1]  

#Adds "Seafood" to a list
productType1 = []
product = "Seafood"
for i in range(len(cProductNames1)):
    productType1.append(product)

#Adds today's date to a list
dates1 = []
todays_date = date.today()
for i in range(len(cProductNames1)):
    dates1.append(todays_date)

#Adds the store name to a list
store1 = []
for i in range(len(cProductNames1)):
    store1.append('Walmart')
    
time.sleep(10)
    
#Open a new web browser
driver = webdriver.Chrome()

#Open the web page that we want open and log in
driver.get('https://www.walmart.com/grocery/browse/Seafood?aisle=1255027787101_1255027789152&page=2')

time.sleep(10)

#Grab the webpage as a BeautifulSoup object
soup = BeautifulSoup(driver.page_source,'html.parser')

#Close the webpage
driver.close()

#Obtain Product Names and append to blank list
productNames = soup.find_all("a",class_='productTile__productNameContainer___3wOJS')
cProductNames2 = []                              
for i in range(len(productNames)):
    cProductNames2.append(productNames[i].text.strip())
cProductNames2 = [i.split(",")[0] for i in cProductNames2]

#Checks if a product is in stock, and if so, obtains the Product Price and append to a blank list
checkStock = soup.find_all(class_='productTile__productTileWrapper___G0H8Q')
outOfStock = []
productPrice = soup.find_all("span",class_='Price__salePrice___3YEJa')
cProductPrice2 = []

for i in range(len(checkStock)):
    if 'productTile__outOfStock___2Dlcs' in str(checkStock[i]):
        outOfStock.append("Y")     
    else:
        outOfStock.append("N")

for i in range(len(outOfStock)):
    if outOfStock[i] == "N":
        cProductPrice2.append(productPrice[i].text.strip())
    else:
        cProductPrice2.append(" Out of Stock")
cProductPrice2 = [e[1:] for e in cProductPrice2]

pricePerUnit = soup.find_all("a",class_='productTile__productNameContainer___3wOJS')
cPricePerUnit2 = []                            
for i in range(len(pricePerUnit)):
    cPricePerUnit2.append(productNames[i].text.strip())
cPricePerUnit2 = [e.partition(',')[2] for e in cPricePerUnit2]  

#Adds "Seafood" to a list
productType2 = []
product = "Seafood"
for i in range(len(cProductNames2)):
    productType2.append(product)

#Adds today's date to a list
dates2 = []
todays_date = date.today()
for i in range(len(cProductNames2)):
    dates2.append(todays_date)

#Adds the store name to a list
store2 = []
for i in range(len(cProductNames2)):
    store2.append('Walmart')

#Combines list from 1st and 2nd page of results
store = store1 + store2
dates = dates1 + dates2
productType = productType1 + productType2
cProductNames = cProductNames1 + cProductNames2
cProductPrice = cProductPrice1 + cProductPrice2
cPricePerUnit = cPricePerUnit1 + cPricePerUnit2

#Combines all lists into one .csv file
WalmartData = {'Store':store,'Date': dates,'Product Type':productType, 'Product Name':cProductNames,'Product Price':cProductPrice,'Price Per Unit':cPricePerUnit}
WalmartDataframe = pd.DataFrame(data=WalmartData)
WalmartDataframe.to_csv('Walmart '+product+' '+str(todays_date)+'.csv',index = False, header=True)

# %%
from selenium import webdriver
from datetime import date
import time
from bs4 import BeautifulSoup
import urllib.request
import pandas as pd
import numpy as np

#Open a new web browser
driver = webdriver.Chrome()

#Open the web page that we want open and log in
driver.get('https://www.walmart.com/grocery/browse/Fresh-Vegetables?aisle=1255027787131_1255027789453')

time.sleep(10)

#Grab the webpage as a BeautifulSoup object
soup = BeautifulSoup(driver.page_source,'html.parser')

#Close the webpage
driver.close()

#Obtain Product Names and append to blank list
productNames = soup.find_all("a",class_='productTile__productNameContainer___3wOJS')
cProductNames1 = []                              
for i in range(len(productNames)):
    cProductNames1.append(productNames[i].text.strip())
cProductNames1 = [i.split(",")[0] for i in cProductNames1]

#Checks if a product is in stock, and if so, obtains the Product Price and append to a blank list
checkStock = soup.find_all(class_='productTile__productTileWrapper___G0H8Q')
outOfStock = []
productPrice = soup.find_all("span",class_='Price__salePrice___3YEJa')
cProductPrice1 = []

for i in range(len(checkStock)):
    if 'productTile__outOfStock___2Dlcs' in str(checkStock[i]):
        outOfStock.append("Y")     
    else:
        outOfStock.append("N")

for i in range(len(outOfStock)):
    if outOfStock[i] == "N":
        cProductPrice1.append(productPrice[i].text.strip())
    else:
        cProductPrice1.append(" Out of Stock")
cProductPrice1 = [e[1:] for e in cProductPrice1]

pricePerUnit = soup.find_all("a",class_='productTile__productNameContainer___3wOJS')
cPricePerUnit1 = []                            
for i in range(len(pricePerUnit)):
    cPricePerUnit1.append(productNames[i].text.strip())
cPricePerUnit1 = [e.partition(',')[2] for e in cPricePerUnit1]  

#Adds "Fresh Vegetables" to a list
productType1 = []
product = "Fresh Vegetables"
for i in range(len(cProductNames1)):
    productType1.append(product)

#Adds today's date to a list
dates1 = []
todays_date = date.today()
for i in range(len(cProductNames1)):
    dates1.append(todays_date)

#Adds the store name to a list
store1 = []
for i in range(len(cProductNames1)):
    store1.append('Walmart')
    
time.sleep(10)
    
#Open a new web browser
driver = webdriver.Chrome()

#Open the web page that we want open and log in
driver.get('https://www.walmart.com/grocery/browse/Fresh-Vegetables?aisle=1255027787131_1255027789453&page=2')

time.sleep(10)

#Grab the webpage as a BeautifulSoup object
soup = BeautifulSoup(driver.page_source,'html.parser')

#Close the webpage
driver.close()

#Obtain Product Names and append to blank list
productNames = soup.find_all("a",class_='productTile__productNameContainer___3wOJS')
cProductNames2 = []                              
for i in range(len(productNames)):
    cProductNames2.append(productNames[i].text.strip())
cProductNames2 = [i.split(",")[0] for i in cProductNames2]

#Checks if a product is in stock, and if so, obtains the Product Price and append to a blank list
checkStock = soup.find_all(class_='productTile__productTileWrapper___G0H8Q')
outOfStock = []
productPrice = soup.find_all("span",class_='Price__salePrice___3YEJa')
cProductPrice2 = []

for i in range(len(checkStock)):
    if 'productTile__outOfStock___2Dlcs' in str(checkStock[i]):
        outOfStock.append("Y")     
    else:
        outOfStock.append("N")

for i in range(len(outOfStock)):
    if outOfStock[i] == "N":
        cProductPrice2.append(productPrice[i].text.strip())
    else:
        cProductPrice2.append(" Out of Stock")
cProductPrice2 = [e[1:] for e in cProductPrice2]

pricePerUnit = soup.find_all("a",class_='productTile__productNameContainer___3wOJS')
cPricePerUnit2 = []                            
for i in range(len(pricePerUnit)):
    cPricePerUnit2.append(productNames[i].text.strip())
cPricePerUnit2 = [e.partition(',')[2] for e in cPricePerUnit2]  

#Adds "Fresh Vegetables" to a list
productType2 = []
product = "Fresh Vegetables"
for i in range(len(cProductNames2)):
    productType2.append(product)

#Adds today's date to a list
dates2 = []
todays_date = date.today()
for i in range(len(cProductNames2)):
    dates2.append(todays_date)

#Adds the store name to a list
store2 = []
for i in range(len(cProductNames2)):
    store2.append('Walmart')

#Combines list from 1st and 2nd page of results
store = store1 + store2
dates = dates1 + dates2
productType = productType1 + productType2
cProductNames = cProductNames1 + cProductNames2
cProductPrice = cProductPrice1 + cProductPrice2
cPricePerUnit = cPricePerUnit1 + cPricePerUnit2

#Combines all lists into one .csv file
WalmartData = {'Store':store,'Date': dates,'Product Type':productType, 'Product Name':cProductNames,'Product Price':cProductPrice,'Price Per Unit':cPricePerUnit}
WalmartDataframe = pd.DataFrame(data=WalmartData)
WalmartDataframe.to_csv('Walmart '+product+' '+str(todays_date)+'.csv',index = False, header=True)

# %%
from selenium import webdriver
from datetime import date
import time
from bs4 import BeautifulSoup
import urllib.request
import pandas as pd
import numpy as np

#Open a new web browser
driver = webdriver.Chrome()

#Open the web page that we want open and log in
driver.get('https://www.walmart.com/grocery/browse/Fresh-Fruit?aisle=1255027787131_1255027788181')

time.sleep(10)

#Grab the webpage as a BeautifulSoup object
soup = BeautifulSoup(driver.page_source,'html.parser')

#Close the webpage
driver.close()

#Obtain Product Names and append to blank list
productNames = soup.find_all("a",class_='productTile__productNameContainer___3wOJS')
cProductNames1 = []                              
for i in range(len(productNames)):
    cProductNames1.append(productNames[i].text.strip())
cProductNames1 = [i.split(",")[0] for i in cProductNames1]

#Checks if a product is in stock, and if so, obtains the Product Price and append to a blank list
checkStock = soup.find_all(class_='productTile__productTileWrapper___G0H8Q')
outOfStock = []
productPrice = soup.find_all("span",class_='Price__salePrice___3YEJa')
cProductPrice1 = []

for i in range(len(checkStock)):
    if 'productTile__outOfStock___2Dlcs' in str(checkStock[i]):
        outOfStock.append("Y")     
    else:
        outOfStock.append("N")

for i in range(len(outOfStock)):
    if outOfStock[i] == "N":
        cProductPrice1.append(productPrice[i].text.strip())
    else:
        cProductPrice1.append(" Out of Stock")
cProductPrice1 = [e[1:] for e in cProductPrice1]
#del cProductPrice1[-1]

pricePerUnit = soup.find_all("a",class_='productTile__productNameContainer___3wOJS')
cPricePerUnit1 = []                            
for i in range(len(pricePerUnit)):
    cPricePerUnit1.append(productNames[i].text.strip())
cPricePerUnit1 = [e.partition(',')[2] for e in cPricePerUnit1]  

#Adds "Fresh Fruit" to a list
productType1 = []
product = "Fresh Fruit"
for i in range(len(cProductNames1)):
    productType1.append(product)

#Adds today's date to a list
dates1 = []
todays_date = date.today()
for i in range(len(cProductNames1)):
    dates1.append(todays_date)

#Adds the store name to a list
store1 = []
for i in range(len(cProductNames1)):
    store1.append('Walmart')
    
time.sleep(10)
    
#Open a new web browser
driver = webdriver.Chrome()

#Open the web page that we want open and log in
driver.get('https://www.walmart.com/grocery/browse/Fresh-Fruit?aisle=1255027787131_1255027788181&page=2')

time.sleep(10)

#Grab the webpage as a BeautifulSoup object
soup = BeautifulSoup(driver.page_source,'html.parser')

#Close the webpage
driver.close()

#Obtain Product Names and append to blank list
productNames = soup.find_all("a",class_='productTile__productNameContainer___3wOJS')
cProductNames2 = []                              
for i in range(len(productNames)):
    cProductNames2.append(productNames[i].text.strip())
cProductNames2 = [i.split(",")[0] for i in cProductNames2]

#Checks if a product is in stock, and if so, obtains the Product Price and append to a blank list
checkStock = soup.find_all(class_='productTile__productTileWrapper___G0H8Q')
outOfStock = []
productPrice = soup.find_all("span",class_='Price__salePrice___3YEJa')
cProductPrice2 = []

for i in range(len(checkStock)):
    if 'productTile__outOfStock___2Dlcs' in str(checkStock[i]):
        outOfStock.append("Y")     
    else:
        outOfStock.append("N")

for i in range(len(outOfStock)):
    if outOfStock[i] == "N":
        cProductPrice2.append(productPrice[i].text.strip())
    else:
        cProductPrice2.append(" Out of Stock")
cProductPrice2 = [e[1:] for e in cProductPrice2]

pricePerUnit = soup.find_all("a",class_='productTile__productNameContainer___3wOJS')
cPricePerUnit2 = []                            
for i in range(len(pricePerUnit)):
    cPricePerUnit2.append(productNames[i].text.strip())
cPricePerUnit2 = [e.partition(',')[2] for e in cPricePerUnit2]  

#Adds "Fresh Fruit" to a list
productType2 = []
product = "Fresh Fruit"
for i in range(len(cProductNames2)):
    productType2.append(product)

#Adds today's date to a list
dates2 = []
todays_date = date.today()
for i in range(len(cProductNames2)):
    dates2.append(todays_date)

#Adds the store name to a list
store2 = []
for i in range(len(cProductNames2)):
    store2.append('Walmart')

#Combines list from 1st and 2nd page of results
store = store1 + store2
dates = dates1 + dates2
productType = productType1 + productType2
cProductNames = cProductNames1 + cProductNames2
cProductPrice = cProductPrice1 + cProductPrice2
cPricePerUnit = cPricePerUnit1 + cPricePerUnit2

#Combines all lists into one .csv file
WalmartData = {'Store':store,'Date': dates,'Product Type':productType, 'Product Name':cProductNames,'Product Price':cProductPrice,'Price Per Unit':cPricePerUnit}
WalmartDataframe = pd.DataFrame(data=WalmartData)
WalmartDataframe.to_csv('Walmart '+product+' '+str(todays_date)+'.csv',index = False, header=True)

# %%
from selenium import webdriver
from datetime import date
import time
from bs4 import BeautifulSoup
import urllib.request
import pandas as pd
import numpy as np

#Open a new web browser
driver = webdriver.Chrome()

#Open the web page that we want open and log in
driver.get('https://www.walmart.com/grocery/browse/Milk?aisle=1255027787061_1255027788656')

time.sleep(10)

#Grab the webpage as a BeautifulSoup object
soup = BeautifulSoup(driver.page_source,'html.parser')

#Close the webpage
driver.close()

#Obtain Product Names and append to blank list
productNames = soup.find_all("a",class_='productTile__productNameContainer___3wOJS')
cProductNames1 = []                              
for i in range(len(productNames)):
    cProductNames1.append(productNames[i].text.strip())
cProductNames1 = [i.split(",")[0] for i in cProductNames1]

#Checks if a product is in stock, and if so, obtains the Product Price and append to a blank list
checkStock = soup.find_all(class_='productTile__productTileWrapper___G0H8Q')
outOfStock = []
productPrice = soup.find_all("span",class_='Price__salePrice___3YEJa')
cProductPrice1 = []

for i in range(len(checkStock)):
    if 'productTile__outOfStock___2Dlcs' in str(checkStock[i]):
        outOfStock.append("Y")     
    else:
        outOfStock.append("N")

for i in range(len(outOfStock)):
    if outOfStock[i] == "N":
        cProductPrice1.append(productPrice[i].text.strip())
    else:
        cProductPrice1.append(" Out of Stock")
cProductPrice1 = [e[1:] for e in cProductPrice1]

pricePerUnit = soup.find_all("a",class_='productTile__productNameContainer___3wOJS')
cPricePerUnit1 = []                            
for i in range(len(pricePerUnit)):
    cPricePerUnit1.append(productNames[i].text.strip())
cPricePerUnit1 = [e.partition(',')[2] for e in cPricePerUnit1]  

#Adds "Dairy" to a list
productType1 = []
product = "Dairy"
for i in range(len(cProductNames1)):
    productType1.append(product)

#Adds today's date to a list
dates1 = []
todays_date = date.today()
for i in range(len(cProductNames1)):
    dates1.append(todays_date)

#Adds the store name to a list
store1 = []
for i in range(len(cProductNames1)):
    store1.append('Walmart')
    
time.sleep(10)
    
#Open a new web browser
driver = webdriver.Chrome()

#Open the web page that we want open and log in
driver.get('https://www.walmart.com/grocery/browse/Cheese?aisle=1255027787061_1255027787521')

time.sleep(10)

#Grab the webpage as a BeautifulSoup object
soup = BeautifulSoup(driver.page_source,'html.parser')

#Close the webpage
driver.close()

#Obtain Product Names and append to blank list
productNames = soup.find_all("a",class_='productTile__productNameContainer___3wOJS')
cProductNames2 = []                              
for i in range(len(productNames)):
    cProductNames2.append(productNames[i].text.strip())
cProductNames2 = [i.split(",")[0] for i in cProductNames2]

#Checks if a product is in stock, and if so, obtains the Product Price and append to a blank list
checkStock = soup.find_all(class_='productTile__productTileWrapper___G0H8Q')
outOfStock = []
productPrice = soup.find_all("span",class_='Price__salePrice___3YEJa')
cProductPrice2 = []

for i in range(len(checkStock)):
    if 'productTile__outOfStock___2Dlcs' in str(checkStock[i]):
        outOfStock.append("Y")     
    else:
        outOfStock.append("N")

for i in range(len(outOfStock)):
    if outOfStock[i] == "N":
        cProductPrice2.append(productPrice[i].text.strip())
    else:
        cProductPrice2.append(" Out of Stock")
cProductPrice2 = [e[1:] for e in cProductPrice2]

pricePerUnit = soup.find_all("a",class_='productTile__productNameContainer___3wOJS')
cPricePerUnit2 = []                            
for i in range(len(pricePerUnit)):
    cPricePerUnit2.append(productNames[i].text.strip())
cPricePerUnit2 = [e.partition(',')[2] for e in cPricePerUnit2]  

#Adds "Dairy" to a list
productType2 = []
product = "Dairy"
for i in range(len(cProductNames2)):
    productType2.append(product)

#Adds today's date to a list
dates2 = []
todays_date = date.today()
for i in range(len(cProductNames2)):
    dates2.append(todays_date)

#Adds the store name to a list
store2 = []
for i in range(len(cProductNames2)):
    store2.append('Walmart')
    
time.sleep(10)
    
#Open a new web browser
driver = webdriver.Chrome()

#Open the web page that we want open and log in
driver.get('https://www.walmart.com/grocery/browse/Eggs?aisle=1255027787061_1255027787921')

time.sleep(10)

#Grab the webpage as a BeautifulSoup object
soup = BeautifulSoup(driver.page_source,'html.parser')

#Close the webpage
driver.close()

#Obtain Product Names and append to blank list
productNames = soup.find_all("a",class_='productTile__productNameContainer___3wOJS')
cProductNames3 = []                              
for i in range(len(productNames)):
    cProductNames3.append(productNames[i].text.strip())
cProductNames3 = [i.split(",")[0] for i in cProductNames3]

#Checks if a product is in stock, and if so, obtains the Product Price and append to a blank list
checkStock = soup.find_all(class_='productTile__productTileWrapper___G0H8Q')
outOfStock = []
productPrice = soup.find_all("span",class_='Price__salePrice___3YEJa')
cProductPrice3 = []

for i in range(len(checkStock)):
    if 'productTile__outOfStock___2Dlcs' in str(checkStock[i]):
        outOfStock.append("Y")     
    else:
        outOfStock.append("N")

for i in range(len(outOfStock)):
    if outOfStock[i] == "N":
        cProductPrice3.append(productPrice[i].text.strip())
    else:
        cProductPrice3.append(" Out of Stock")
cProductPrice3 = [e[1:] for e in cProductPrice3]

pricePerUnit = soup.find_all("a",class_='productTile__productNameContainer___3wOJS')
cPricePerUnit3 = []                            
for i in range(len(pricePerUnit)):
    cPricePerUnit3.append(productNames[i].text.strip())
cPricePerUnit3 = [e.partition(',')[2] for e in cPricePerUnit3]  

#Adds "Dairy" to a list
productType3 = []
product = "Dairy"
for i in range(len(cProductNames3)):
    productType3.append(product)

#Adds today's date to a list
dates3 = []
todays_date = date.today()
for i in range(len(cProductNames3)):
    dates3.append(todays_date)

#Adds the store name to a list
store3 = []
for i in range(len(cProductNames3)):
    store3.append('Walmart')

time.sleep(10)
    
#Open a new web browser
driver = webdriver.Chrome()

#Open the web page that we want open and log in
driver.get('https://www.walmart.com/grocery/browse/Butter-&-Margarine?aisle=1255027787061_1255027787401')

time.sleep(10)

#Grab the webpage as a BeautifulSoup object
soup = BeautifulSoup(driver.page_source,'html.parser')

#Close the webpage
driver.close()

#Obtain Product Names and append to blank list
productNames = soup.find_all("a",class_='productTile__productNameContainer___3wOJS')
cProductNames4 = []                              
for i in range(len(productNames)):
    cProductNames4.append(productNames[i].text.strip())
cProductNames4 = [i.split(",")[0] for i in cProductNames4]

#Checks if a product is in stock, and if so, obtains the Product Price and append to a blank list
checkStock = soup.find_all(class_='productTile__productTileWrapper___G0H8Q')
outOfStock = []
productPrice = soup.find_all("span",class_='Price__salePrice___3YEJa')
cProductPrice4 = []

for i in range(len(checkStock)):
    if 'productTile__outOfStock___2Dlcs' in str(checkStock[i]):
        outOfStock.append("Y")     
    else:
        outOfStock.append("N")

for i in range(len(outOfStock)):
    if outOfStock[i] == "N":
        cProductPrice4.append(productPrice[i].text.strip())
    else:
        cProductPrice4.append(" Out of Stock")
cProductPrice4 = [e[1:] for e in cProductPrice4]

pricePerUnit = soup.find_all("a",class_='productTile__productNameContainer___3wOJS')
cPricePerUnit4 = []                            
for i in range(len(pricePerUnit)):
    cPricePerUnit4.append(productNames[i].text.strip())
cPricePerUnit4 = [e.partition(',')[2] for e in cPricePerUnit4]  

#Adds "Dairy" to a list
productType4 = []
product = "Dairy"
for i in range(len(cProductNames4)):
    productType4.append(product)

#Adds today's date to a list
dates4 = []
todays_date = date.today()
for i in range(len(cProductNames4)):
    dates4.append(todays_date)

#Adds the store name to a list
store4 = []
for i in range(len(cProductNames4)):
    store4.append('Walmart')

#Combines list from 1st and 2nd page of results
store = store1 + store2 + store3 + store4
dates = dates1 + dates2 + dates3 + dates4
productType = productType1 + productType2 + productType3 + productType4
cProductNames = cProductNames1 + cProductNames2 + cProductNames3 + cProductNames4
cProductPrice = cProductPrice1 + cProductPrice2 + cProductPrice3 + cProductPrice4
cPricePerUnit = cPricePerUnit1 + cPricePerUnit2 + cPricePerUnit3 + cPricePerUnit4

#Combines all lists into one .csv file
WalmartData = {'Store':store,'Date': dates,'Product Type':productType, 'Product Name':cProductNames,'Product Price':cProductPrice,'Price Per Unit':cPricePerUnit}
WalmartDataframe = pd.DataFrame(data=WalmartData)
WalmartDataframe.to_csv('Walmart '+product+' '+str(todays_date)+'.csv',index = False, header=True)

# %%
from selenium import webdriver
from datetime import date
import time
from bs4 import BeautifulSoup
import urllib.request
import pandas as pd
import numpy as np

#Open a new web browser
driver = webdriver.Chrome()

#Open the web page that we want open and log in
driver.get('https://www.walmart.com/grocery/browse/Chicken?aisle=1255027787101_1255027788877')

time.sleep(10)

#Grab the webpage as a BeautifulSoup object
soup = BeautifulSoup(driver.page_source,'html.parser')

#Close the webpage
driver.close()

#Obtain Product Names and append to blank list
productNames = soup.find_all("a",class_='productTile__productNameContainer___3wOJS')
cProductNames1 = []                              
for i in range(len(productNames)):
    cProductNames1.append(productNames[i].text.strip())
cProductNames1 = [i.split(",")[0] for i in cProductNames1]

#Checks if a product is in stock, and if so, obtains the Product Price and append to a blank list
checkStock = soup.find_all(class_='productTile__productTileWrapper___G0H8Q')
outOfStock = []
productPrice = soup.find_all("span",class_='Price__salePrice___3YEJa')
cProductPrice1 = []

for i in range(len(checkStock)):
    if 'productTile__outOfStock___2Dlcs' in str(checkStock[i]):
        outOfStock.append("Y")     
    else:
        outOfStock.append("N")

for i in range(len(outOfStock)):
    if outOfStock[i] == "N":
        cProductPrice1.append(productPrice[i].text.strip())
    else:
        cProductPrice1.append(" Out of Stock")
cProductPrice1 = [e[1:] for e in cProductPrice1]

pricePerUnit = soup.find_all("a",class_='productTile__productNameContainer___3wOJS')
cPricePerUnit1 = []                            
for i in range(len(pricePerUnit)):
    cPricePerUnit1.append(productNames[i].text.strip())
cPricePerUnit1 = [e.partition(',')[2] for e in cPricePerUnit1]  

#Adds "Meat" to a list
productType1 = []
product = "Meat"
for i in range(len(cProductNames1)):
    productType1.append(product)

#Adds today's date to a list
dates1 = []
todays_date = date.today()
for i in range(len(cProductNames1)):
    dates1.append(todays_date)

#Adds the store name to a list
store1 = []
for i in range(len(cProductNames1)):
    store1.append('Walmart')
    
time.sleep(10)
    
#Open a new web browser
driver = webdriver.Chrome()

#Open the web page that we want open and log in
driver.get('https://www.walmart.com/grocery/browse/Chicken?aisle=1255027787101_1255027788877&page=2')

time.sleep(10)

#Grab the webpage as a BeautifulSoup object
soup = BeautifulSoup(driver.page_source,'html.parser')

#Close the webpage
driver.close()

#Obtain Product Names and append to blank list
productNames = soup.find_all("a",class_='productTile__productNameContainer___3wOJS')
cProductNames2 = []                              
for i in range(len(productNames)):
    cProductNames2.append(productNames[i].text.strip())
cProductNames2 = [i.split(",")[0] for i in cProductNames2]

#Checks if a product is in stock, and if so, obtains the Product Price and append to a blank list
checkStock = soup.find_all(class_='productTile__productTileWrapper___G0H8Q')
outOfStock = []
productPrice = soup.find_all("span",class_='Price__salePrice___3YEJa')
cProductPrice2 = []

for i in range(len(checkStock)):
    if 'productTile__outOfStock___2Dlcs' in str(checkStock[i]):
        outOfStock.append("Y")     
    else:
        outOfStock.append("N")

for i in range(len(outOfStock)):
    if outOfStock[i] == "N":
        cProductPrice2.append(productPrice[i].text.strip())
    else:
        cProductPrice2.append(" Out of Stock")
cProductPrice2 = [e[1:] for e in cProductPrice2]

pricePerUnit = soup.find_all("a",class_='productTile__productNameContainer___3wOJS')
cPricePerUnit2 = []                            
for i in range(len(pricePerUnit)):
    cPricePerUnit2.append(productNames[i].text.strip())
cPricePerUnit2 = [e.partition(',')[2] for e in cPricePerUnit2]  

#Adds "Meat" to a list
productType2 = []
product = "Meat"
for i in range(len(cProductNames2)):
    productType2.append(product)

#Adds today's date to a list
dates2 = []
todays_date = date.today()
for i in range(len(cProductNames2)):
    dates2.append(todays_date)

#Adds the store name to a list
store2 = []
for i in range(len(cProductNames2)):
    store2.append('Walmart')
    
time.sleep(10)
    
#Open a new web browser
driver = webdriver.Chrome()

#Open the web page that we want open and log in
driver.get('https://www.walmart.com/grocery/browse/Beef?aisle=1255027787101_1255031542269')

time.sleep(10)

#Grab the webpage as a BeautifulSoup object
soup = BeautifulSoup(driver.page_source,'html.parser')

#Close the webpage
driver.close()

#Obtain Product Names and append to blank list
productNames = soup.find_all("a",class_='productTile__productNameContainer___3wOJS')
cProductNames3 = []                              
for i in range(len(productNames)):
    cProductNames3.append(productNames[i].text.strip())
cProductNames3 = [i.split(",")[0] for i in cProductNames3]

#Checks if a product is in stock, and if so, obtains the Product Price and append to a blank list
checkStock = soup.find_all(class_='productTile__productTileWrapper___G0H8Q')
outOfStock = []
productPrice = soup.find_all("span",class_='Price__salePrice___3YEJa')
cProductPrice3 = []

for i in range(len(checkStock)):
    if 'productTile__outOfStock___2Dlcs' in str(checkStock[i]):
        outOfStock.append("Y")     
    else:
        outOfStock.append("N")

for i in range(len(outOfStock)):
    if outOfStock[i] == "N":
        cProductPrice3.append(productPrice[i].text.strip())
    else:
        cProductPrice3.append(" Out of Stock")
cProductPrice3 = [e[1:] for e in cProductPrice3]

pricePerUnit = soup.find_all("a",class_='productTile__productNameContainer___3wOJS')
cPricePerUnit3 = []                            
for i in range(len(pricePerUnit)):
    cPricePerUnit3.append(productNames[i].text.strip())
cPricePerUnit3 = [e.partition(',')[2] for e in cPricePerUnit3]  

#Adds "Meat" to a list
productType3 = []
product = "Meat"
for i in range(len(cProductNames3)):
    productType3.append(product)

#Adds today's date to a list
dates3 = []
todays_date = date.today()
for i in range(len(cProductNames3)):
    dates3.append(todays_date)

#Adds the store name to a list
store3 = []
for i in range(len(cProductNames3)):
    store3.append('Walmart')

time.sleep(10)
    
#Open a new web browser
driver = webdriver.Chrome()

#Open the web page that we want open and log in
driver.get('https://www.walmart.com/grocery/browse/Beef?aisle=1255027787101_1255031542269&page=2')

time.sleep(10)

#Grab the webpage as a BeautifulSoup object
soup = BeautifulSoup(driver.page_source,'html.parser')

#Close the webpage
driver.close()

#Obtain Product Names and append to blank list
productNames = soup.find_all("a",class_='productTile__productNameContainer___3wOJS')
cProductNames4 = []                              
for i in range(len(productNames)):
    cProductNames4.append(productNames[i].text.strip())
cProductNames4 = [i.split(",")[0] for i in cProductNames4]

#Checks if a product is in stock, and if so, obtains the Product Price and append to a blank list
checkStock = soup.find_all(class_='productTile__productTileWrapper___G0H8Q')
outOfStock = []
productPrice = soup.find_all("span",class_='Price__salePrice___3YEJa')
cProductPrice4 = []

for i in range(len(checkStock)):
    if 'productTile__outOfStock___2Dlcs' in str(checkStock[i]):
        outOfStock.append("Y")     
    else:
        outOfStock.append("N")

for i in range(len(outOfStock)):
    if outOfStock[i] == "N":
        cProductPrice4.append(productPrice[i].text.strip())
    else:
        cProductPrice4.append(" Out of Stock")
cProductPrice4 = [e[1:] for e in cProductPrice4]

pricePerUnit = soup.find_all("a",class_='productTile__productNameContainer___3wOJS')
cPricePerUnit4 = []                            
for i in range(len(pricePerUnit)):
    cPricePerUnit4.append(productNames[i].text.strip())
cPricePerUnit4 = [e.partition(',')[2] for e in cPricePerUnit4]  

#Adds "Meat" to a list
productType4 = []
product = "Meat"
for i in range(len(cProductNames4)):
    productType4.append(product)

#Adds today's date to a list
dates4 = []
todays_date = date.today()
for i in range(len(cProductNames4)):
    dates4.append(todays_date)

#Adds the store name to a list
store4 = []
for i in range(len(cProductNames4)):
    store4.append('Walmart')

#Combines list from 1st and 2nd page of results
store = store1 + store2 + store3 + store4
dates = dates1 + dates2 + dates3 + dates4
productType = productType1 + productType2 + productType3 + productType4
cProductNames = cProductNames1 + cProductNames2 + cProductNames3 + cProductNames4
cProductPrice = cProductPrice1 + cProductPrice2 + cProductPrice3 + cProductPrice4
cPricePerUnit = cPricePerUnit1 + cPricePerUnit2 + cPricePerUnit3 + cPricePerUnit4

#Combines all lists into one .csv file
WalmartData = {'Store':store,'Date': dates,'Product Type':productType, 'Product Name':cProductNames,'Product Price':cProductPrice,'Price Per Unit':cPricePerUnit}
WalmartDataframe = pd.DataFrame(data=WalmartData)
WalmartDataframe.to_csv('Walmart '+product+' '+str(todays_date)+'.csv',index = False, header=True)

# %%
import os
import glob
import pandas as pd
import numpy as np

os.chdir(r"C:\Users\nickm\Desktop\New folder (2)")
extension = 'csv'
all_filenames = [i for i in glob.glob('*.{}'.format(extension))]
#combine all files in the list
combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames ])
#export to csv
combined_csv.to_csv( "combined_csv.csv", index=False, encoding='utf-8-sig')

combined_csv = pd.read_csv(r'C:\Users\nickm\Desktop\New folder (2)\combined_csv.csv')
combined_price = combined_csv['Price Per Unit'].str.rsplit(",", n = 2, expand = True)   
combined_csv['Unit and Price'] = combined_price[1]

combined_csv.loc[combined_csv['Unit and Price'].isnull(),'Unit and Price'] = combined_price[0] 
combined_csv[['Quantity','Unit']] = combined_csv['Unit and Price'].str.split(n=1, expand=True)
combined_csv['Unit'] = combined_csv['Unit'].fillna('each')
combined_csv.drop(columns=['Price Per Unit'])
combined_csv.rename(columns={"Unit and Price": "Quantity and Unit"})

combined_csv.loc[combined_csv['Quantity'] == 'Half', 'Quantity'] = 0.5
combined_csv.loc[combined_csv['Unit'] == 'L', 'Unit'] = 'LTR'
combined_csv.loc[combined_csv['Unit'].str.contains('oz', na=False), 'Unit'] = 'OZ'
combined_csv.loc[combined_csv['Unit'].str.contains('Oz', na=False), 'Unit'] = 'OZ'
combined_csv.loc[combined_csv['Unit'].str.contains('ounces', na=False), 'Unit'] = 'OZ'
combined_csv.loc[combined_csv['Unit'].str.contains('ounce', na=False), 'Unit'] = 'OZ'
combined_csv.loc[combined_csv['Unit'].str.contains('OZ', na=False), 'Unit'] = 'OZ'
combined_csv.loc[combined_csv['Unit'].str.contains('0z', na=False), 'Unit'] = 'OZ'
combined_csv.loc[combined_csv['Unit'].str.contains('lb', na=False), 'Unit'] = 'LB'
combined_csv.loc[combined_csv['Unit'].str.contains('gal', na=False), 'Unit'] = 'GALLON'
combined_csv.loc[combined_csv['Unit'].str.contains('Gallon', na=False), 'Unit'] = 'GALLON'
combined_csv.loc[combined_csv['Unit'].str.contains('ea', na=False), 'Unit'] = 'EA'
combined_csv.loc[combined_csv['Unit'].str.contains('each', na=False), 'Unit'] = 'EA'
combined_csv.loc[combined_csv['Unit'].str.contains('Each', na=False), 'Unit'] = 'EA'
combined_csv.loc[combined_csv['Unit'].str.contains('count', na=False), 'Unit'] = 'EA'
combined_csv.loc[combined_csv['Unit'].str.contains('Count', na=False), 'Unit'] = 'EA'
combined_csv.loc[combined_csv['Unit'].str.contains('pint', na=False), 'Unit'] = 'PINT'
combined_csv['Quantity in LBS'] = combined_csv['Quantity'].str.extract('(\d+)', expand=False)
combined_csv['Quantity in LBS'] = combined_csv['Quantity in LBS'].astype(float)

gallons_to_pounds = 8.35
liters_to_pounds = 2.205
ounces_to_pounds = .0625
pints_to_pounds = 1.043
quarts_to_pounds = 2.09
        
converted_quantity = []
for i in range(len(combined_csv['Quantity in LBS'])):
    if combined_csv['Unit'][i] == 'GALLON':
        converted_quantity.append(combined_csv['Quantity in LBS'][i] * gallons_to_pounds)
    elif combined_csv['Unit'][i] == 'LTR':
        converted_quantity.append(combined_csv['Quantity in LBS'][i] * liters_to_pounds)
    elif combined_csv['Unit'][i] == 'OZ':
        converted_quantity.append(combined_csv['Quantity in LBS'][i] * ounces_to_pounds)
    elif combined_csv['Unit'][i] == 'PINT':
        converted_quantity.append(combined_csv['Quantity in LBS'][i] * pints_to_pounds)
    elif combined_csv['Unit'][i] == 'QUART':
        converted_quantity.append(combined_csv['Quantity in LBS'][i] * quarts_to_pounds)
    else:
        converted_quantity.append(combined_csv['Quantity in LBS'][i])
        
combined_csv['Quantity in LBS'] = converted_quantity

combined_csv.to_csv( "combined_csv_revised.csv", index=False, encoding='utf-8-sig')

# %%
import pandas as pd
import numpy as np

walmart_df = pd.read_csv(r'C:\Users\nickm\Google Drive\Documents\Fordham University\Web Analytics\Project\Walmart Master File.csv')

#Drop the one redundant column
walmart_df.drop('Price Per Unit',axis = 1, inplace=True)

#Rename Some Columns
walmart_df.rename(columns = {'Quantity':'Old_Quantity'},inplace=True)
walmart_df.rename(columns = {'Product Price':'Price','Unit and Price':'Quantity Sold In','Unit':'Units','Quantity in LBS':'Quantity'},inplace=True)

#We do not have "Sales" data for Walmart, so we will need to insert two blank columns to align with the overall master.
sale_on_this_product = []
for i in range(len(walmart_df['Store'])):
    sale_on_this_product.append(None)
    
if_sale_original_price = []
for i in range(len(walmart_df['Store'])):
    if_sale_original_price.append(None)
    
walmart_df['Sale on This Product?'] = sale_on_this_product
walmart_df['If Sale, Original Price'] = if_sale_original_price
    

#Reorder Walmart columns to match order in overall master file
column_order = ['Date','Store','Product Type','Product Name','Price',
              'Quantity Sold In','Sale on This Product?','If Sale, Original Price','Quantity','Old_Quantity','Units']
walmart_df = walmart_df[column_order]

#Where "Quantity" is blank and "Units" are "EA", put a 1 in the "Quantity" list
quantity = []
for i in range(len(walmart_df['Store'])):
    if walmart_df['Units'][i] == 'EA' and pd.isna(walmart_df['Quantity'][i]) == True:
        quantity.append(1)
    else:
        quantity.append(walmart_df['Quantity'][i])

walmart_df['Quantity'] = quantity

#If "Quantity" is still blank, even after appending the "1"s into the list, drop that observation 
#as something is wrong in the original Walmart code and we have a sufficient number of observations to allow the luxury of dropping.
walmart_df = walmart_df[walmart_df['Quantity'].notna()]

#reset the index before the next loop
walmart_df.reset_index(drop=True,inplace=True)

#Where "Quantity" is 0, input the value from the "Old_Quantity"
quantity2 = []
for i in range(len(walmart_df['Quantity'])):
    if walmart_df['Quantity'][i] == 0:
        quantity2.append(walmart_df['Old_Quantity'][i])
    else:
        quantity2.append(walmart_df['Quantity'][i])

walmart_df['Quantity'] = quantity2

#drop "Old_Quantity" column
walmart_df.drop('Old_Quantity',axis = 1, inplace=True)

#Deal with wierd "x-y" formatting in a few cells in Quantity column by splitting the string, taking first list
#element, and finally converting to a float
quantity3 = []
for i in range(len(walmart_df['Quantity'])):
    if type(walmart_df['Quantity'][i]) == str:
        quantity3.append(float(walmart_df['Quantity'][i].split('-')[0]))
    else:
        quantity3.append(walmart_df['Quantity'][i])

walmart_df['Quantity'] = quantity3

#Scrub "Units" such that we are left with only "EA" and "LBS"
#Labels whose corresponding quantities were left unconverted to LBS as of 11/25/2020: G, Quart 
need_to_be_EA = ['Bunch','ct','Dry Pint','l','Pack','pcs','pk','slices','Slices']
need_to_be_LBS = ['bag','Bag','Clamshell','G','GALLON','LB','Lb Bag','LTR','OZ','Ounce (Family Size)','PINT','Quart']
units = []
for i in range(len(walmart_df['Units'])):
    if walmart_df['Units'][i] in need_to_be_EA:
        units.append('EA')
    elif walmart_df['Units'][i] in need_to_be_LBS:
        units.append('LBS')
    else:
        units.append(walmart_df['Units'][i])

walmart_df['Units'] = units

walmart_df.to_csv(r'C:\Users\nickm\Google Drive\Documents\Fordham University\Web Analytics\Project\Walmart Intermediate.csv',index=False)

walmart_df.head()
